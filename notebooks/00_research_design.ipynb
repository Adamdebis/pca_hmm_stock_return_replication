# %% [markdown]
# # 00 - Research design
#
# This notebook states the replication question and the paper's data-to-trading pipeline. The default dataset is synthetic so the full workflow is deterministic and offline.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.data import make_synthetic_returns
returns = make_synthetic_returns(periods=320, assets=24, seed=42)
print(returns.shape)
returns.head()

# %% [markdown]
# The empirical paper uses weekly S&P 500 returns, a rolling training window, and one-week-ahead forecasts. The synthetic panel only replaces the unavailable historical download; it does not replace the paper's reported numbers.
