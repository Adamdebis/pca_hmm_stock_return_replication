# %% [markdown]
# # 03 - Rolling replication results
#
# This notebook runs the rolling one-week-ahead forecast, evaluates both paper-inspired strategies, and compares them with equal-weight buy-and-hold.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.data import make_synthetic_returns
from src.replication import rolling_backtest
returns = make_synthetic_returns(periods=320, assets=24, seed=42)
results, summary, _ = rolling_backtest(returns, train_periods=260, forecast_periods=20, max_iter=35)
summary

# %% [markdown]
# A high Sharpe ratio in this synthetic demonstration is not a claim about live trading. The paper audit records the missing data, execution, and transaction-cost details that would be needed for a stronger empirical claim.
